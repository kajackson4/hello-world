# %% [markdown]
# Exercise 2:
#
# Write a program that uses `input()` to prompt a user for their name and then welcomes them.

# %%
name = input('What is your name?')
print('Welcome, ', name)
# Out:
# What is your name?Princess Katja of Liechtenstein
# Welcome,  Princess Katja of Liechtenstein

# %% [markdown]
# Exercise 3:
#
# Write a program to prompt the user for hours and rate per hour to compute gross pay.

# %%
hours = input('How many hours did you work?')
rate = input('What is your rate per hour?')
grossPay= int(hours) * int(rate)
print('Your gross pay is: ', grossPay)
# Out:
# How many hours did you work?666
# What is your rate per hour?42
# Your gross pay is:  27972
